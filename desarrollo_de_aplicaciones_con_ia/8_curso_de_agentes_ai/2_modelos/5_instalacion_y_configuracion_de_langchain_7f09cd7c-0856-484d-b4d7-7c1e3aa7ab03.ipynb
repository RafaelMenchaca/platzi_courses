# %% [markdown]
# # ChatModels

# %% [markdown]
# ## OpenAI

# %%
import os
from dotenv import load_dotenv 

load_dotenv()

OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY")

# %%
# !pip install -qU langchain-openai

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model='gpt-4o',
                 temperature=0,
                 max_tokens = 700)

llm_temperature_1 = ChatOpenAI(model='gpt-4o',
                 temperature=1,
                 max_tokens = 700)

# %%
messages = [(
    'system',
    'Eres un profesor de programacion en python. Enseña a programar'
    ),
    (
    'human', 'Quiero instalar python en windows'
    )
           ]

# %%
ai_msg = llm.invoke(messages)
ai_message_temp_1 = llm_temperature_1.invoke(messages)

# %%
print(ai_msg.content)
# Out:
# ¡Claro! Instalar Python en Windows es un proceso sencillo. Aquí tienes una guía paso a paso para hacerlo:
#
# 1. **Descargar el instalador de Python:**
#    - Ve al sitio web oficial de Python: [python.org](https://www.python.org/).
#    - Haz clic en "Downloads" en la barra de navegación superior.
#    - El sitio web debería detectar automáticamente tu sistema operativo y mostrar un botón para descargar la última versión de Python para Windows. Haz clic en ese botón para descargar el instalador.
#
# 2. **Ejecutar el instalador:**
#    - Una vez que se haya descargado el archivo, haz doble clic en él para ejecutarlo.
#    - En la ventana del instalador, asegúrate de marcar la casilla que dice "Add Python to PATH". Esto es importante para poder ejecutar Python desde la línea de comandos.
#    - Luego, haz clic en "Install Now" para comenzar la instalación.
#
# 3. **Verificar la instalación:**
#    - Una vez que la instalación haya finalizado, abre la "Command Prompt" (puedes buscar "cmd" en el menú de inicio).
#    - Escribe `python --version` y presiona Enter. Deberías ver la versión de Python que acabas de instalar.
#    - También puedes verificar `pip`, el gestor de paquetes de Python, escribiendo `pip --version`.
#
# 4. **Configurar el entorno de desarrollo (opcional):**
#    - Aunque puedes escribir y ejecutar scripts de Python directamente desde un editor de texto y la línea de comandos, es recomendable usar un entorno de desarrollo integrado (IDE) para facilitar el proceso de programación.
#    - Algunas opciones populares son PyCharm, Visual Studio Code, y Anaconda (que incluye Jupyter Notebook).
#
# ¡Y eso es todo! Ahora tienes Python instalado en tu sistema Windows y estás listo para comenzar a programar. Si tienes alguna pregunta o necesitas más ayuda, no dudes en preguntar.

# %%
print(ai_message_temp_1.content)
# Out:
# ¡Por supuesto! Aquí tienes una guía paso a paso para instalar Python en una máquina con Windows:
#
# 1. **Descarga de Python**:
#    - Ve al sitio web oficial de Python: [python.org](https://www.python.org/).
#    - Haz clic en el botón "Downloads" en el menú principal.
#    - El sitio web automáticamente te sugerirá la última versión estable de Python para Windows. Haz clic en el enlace para descargar el instalador. Por lo general, tiene un nombre como `python-3.x.x-amd64.exe` o `python-3.x.x.exe`.
#
# 2. **Ejecuta el Instalador**:
#    - Una vez que hayas descargado el archivo, haz doble clic para ejecutarlo.
#    - Importante: Marca la casilla que dice "Add Python 3.x to PATH" antes de proceder. Esto es crucial, ya que permite que ejecutes Python desde cualquier lugar en la línea de comandos.
#    - Selecciona "Install Now" para una instalación fácil y automática.
#
# 3. **Verifica la Instalación**:
#    - Abre el "Símbolo del sistema" (puedes buscarlo como "cmd" en el menú Inicio).
#    - Escribe `python --version` o `python` y presiona Enter. Si el instalador funcionó correctamente, verás la versión de Python que acabas de instalar.
#    - También puedes verificar `pip`, el gestor de paquetes de Python, escribiendo `pip --version`.
#
# 4. **Configuraciones Opcionales**:
#    - Si necesitas instalar Python para todos los usuarios, asegúrate de seleccionar "Customize installation" y marca la opción para instalar para todos los usuarios del sistema.
#    - Puedes explorar más configuraciones avanzadas en la opción "Customize installation".
#
# Ahora Python debería estar completamente instalado y listo para usarse en tu sistema Windows. Puedes comenzar a usarlo con la consola interactiva o instalando un entorno de desarrollo como PyCharm, VSCode, o cualquier otro de tu preferencia. ¡Feliz programación!

# %%
from langchain_core.prompts import ChatPromptTemplate

# Crear una plantilla de prompt para traducciones
prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "Eres un asistente útil que traduce {input_language} a {output_language}.",
        ),
        ("human", "{input}"),
    ]
)

# Encadenar la plantilla con el modelo de Google AI
chain = prompt | llm

# Invocar la cadena con parámetros específicos
chain.invoke(
    {
        "input_language": "English",
        "output_language": "French",
        "input": "I love programming.",
    }
)
# Out:
# AIMessage(content="J'adore la programmation.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 5, 'prompt_tokens': 28, 'total_tokens': 33, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_fa7f5b168b', 'id': 'chatcmpl-D5Lua4ap5s3UB6pyWCY4Hy9n2ZJ49', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c263f-d1d0-7220-9fbf-ae2f2d685687-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 28, 'output_tokens': 5, 'total_tokens': 33, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
